# %% [markdown]
# <a href="https://colab.research.google.com/github/afrojaakter/Pattern-Recognition/blob/main/SVD_alignment_importance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
from skimage import transform
plt.rcParams['figure.figsize'] = [12,12]
plt.rcParams.update({'font.size': 18})

n = 1000
q = int(n/4)
X = np.zeros((n,n))
X[(q-1):(3*q),(q-1):(3*q)] = 1


#rotation 
X_rot = skimage.transform.rotate(X,10)
X_rot[np.nonzero(X_rot)] = 1

plt.subplot(1,2,1)
plt.imshow(X)
plt.set_cmap('gray')
plt.axis('off')
plt.title('Unrotated Matrix')

plt.subplot(1,2,2)
plt.imshow(X_rot)
plt.set_cmap('gray')
plt.axis('off')
plt.title('Rotated Matrix')
plt.show()

# %%
U, S, VT = np.linalg.svd(X,full_matrices=0)
plt.subplot(1,2,1)
plt.rcParams['figure.figsize'] = [25,7]
plt.semilogy(S,'-o',color='k')
plt.ylim((10**(-16),10**(4)+1))
plt.yticks(np.power(10,np.arange(-16,4,4, dtype=float)))
plt.xticks(np.arange(0,1000,250))
plt.grid()
plt.title('Unrotated Matrix: Spectrum')


#svd for rotated matrix
U_rot, S_rot, VT_rot = np.linalg.svd(X_rot,full_matrices=0)
plt.subplot(1,2,2)
plt.rcParams['figure.figsize'] = [25,7]
plt.semilogy(S_rot,'-o',color='k')
plt.ylim((10**(-16),10**(4)+1))
plt.yticks(np.power(10,np.arange(-16,4,4, dtype=float)))
plt.xticks(np.arange(0,1000,250))
plt.grid()
plt.title('Rotated Matrix: Spectrum')
plt.show()
